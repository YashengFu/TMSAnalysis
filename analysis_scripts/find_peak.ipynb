# %% [markdown]
# ## This is a test script to understand the function of python functions
# ### find peak algorithm

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.misc import electrocardiogram
from scipy.signal import find_peaks
x = electrocardiogram()[2000:4000]
peaks, _ = find_peaks(x, height=0.6)
plt.plot(x,"ro",markersize=0.2)
plt.plot(peaks, x[peaks], "x")
plt.xlim(500,750)
plt.plot(np.zeros_like(x), "--", color="gray")
plt.show()
